# %% [markdown]
# ![kk_p1_nyeri.PNG](data:image/png;base64,...)

# %% [markdown]
# # Welcome to Back 2 Basics: Conditional Statements in Python 🤖✨
#
#
#
# ⚔️ I am your hosts, [Ngesa Marvin, GDE ML ](https://twitter.com/Ngesa254)!🐍
#
#
# 🏹 Our goal is to get you enough knowledge to confidently use Python in your next project.
#
# * Tools you will master: Python

# %% [markdown]
# ⚓  🗡️ 🏴‍☠️
#
# Level: Beginner (No previous experience necessary)
#
# In this session we will explore conditional statements and their functionality.
#
# Here's what we will cover today:
#
# 1. Definition
# 2. Conditional Statements in Python 🐍 🎩
# 3. if
# 4. if-else
# 5. if-elif-else🧹☕.
# 6. Next steps... and more! 🏆✨➡️

# %% [markdown]
# ### Defination

# %% [markdown]
# A conditional statement is a Boolean expression that, if True, executes a piece of code.
#
# It allows programs to branch out into different paths based on Boolean expressions result in True or False outcomes.

# %%
# The print Statement

attentive_in_lesson = True

if attentive_in_lesson:
  pass

else:
  pass

# %% [markdown]
# There are three types of conditional statements in Python:
#
# *   if
# *   if-else
# *   if-elif-else

# %% [markdown]
# ## Thank you 💖✨✨
#
# Congratulations on completing Conditional Statements in Python
#
# And thank you for your time and attention!
#
# Questions? Comments? Ideas? Inspos?
#
# *   Let me know [@ngesa254]( https://twitter.com/Ngesa254 )!
#
# See you soon at the next event near you!
#
# "#GDE #ML #Back2Basics #KerasKnights"

# %% [markdown]
# ![twitter 3.PNG](data:image/png;base64,...)
